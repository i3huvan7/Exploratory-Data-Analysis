# %%
import pandas as pa
import seaborn as sns
data = pa.read_csv(r"C:\Users\bhuva\Documents\Projects\EDA\genz_college_admission_prediction.csv")
data
# Out:
#         student_id  age  gender       state  family_income  high_school_gpa  \
# 0                1   22    Male        Ohio          32560             3.20
# 1                2   19    Male    Virginia          39084             4.00
# 2                3   20    Male        Ohio          21615             2.90
# 3                4   22    Male    Illinois         109493             3.86
# 4                5   18    Male     Florida          50314             2.50
# ...            ...  ...     ...         ...            ...              ...
# 999995      999996   20  Female    New York         127978             3.98
# 999996      999997   16    Male        Ohio          47661             3.49
# 999997      999998   21  Female  Washington          88044             2.77
# 999998      999999   17  Female    Virginia          55654             3.71
# 999999     1000000   18    Male  California          59923             3.41
#
# ...

# %%
data.describe()
# Out:
#            student_id             age   family_income  high_school_gpa  \
# count  1000000.000000  1000000.000000  1000000.000000   1000000.000000
# mean    500000.500000       19.000294    71701.069023         3.188329
# std     288675.278933        1.999321    47253.555181         0.476299
# min          1.000000       16.000000     2124.000000         0.870000
# 25%     250000.750000       17.000000    39953.000000         2.860000
# 50%     500000.500000       19.000000    59877.000000         3.200000
# 75%     750000.250000       21.000000    89688.000000         3.540000
# max    1000000.000000       22.000000   977775.000000         4.000000
#
#             sat_score       act_score  attendance_rate      ap_courses  \
# count  1000000.000000  1000000.000000   1000000.000000  1000000.000000
# mean      1099.198467       23.468139        91.748151        2.999739
# std        217.409113        5.908590         5.526156        1.729285
# ...

# %%
#so, there is no missing rows or columns

# %%
#Lets see the unique values in the columns

# %%
data.nunique()
# Out:
# student_id               1000000
# age                            7
# gender                         3
# state                         10
# family_income             182270
# high_school_gpa              299
# sat_score                   1201
# act_score                     36
# attendance_rate              335
# ap_courses                    13
# extracurricular_count         16
# volunteer_hours              451
# leadership_positions           9
# coding_projects               12
# social_media_hours           127
# online_certifications         13
# essay_score                  752
# recommendation_score         638
# interview_score              886
# admission_status               2
# dtype: int64

# %%
#to get No. of distinct values of a particular column

# %%
data["state"].nunique()
# Out:
# 10

# %%
#to get The distict values

# %%
data["state"].unique()
# Out:
# array(['Ohio', 'Virginia', 'Illinois', 'Florida', 'California',
#        'New York', 'North Carolina', 'Texas', 'Georgia', 'Washington'],
#       dtype=object)

# %%
#Cleaning the data

# %%
data.isnull()
# Out:
#         student_id    age  gender  state  family_income  high_school_gpa  \
# 0            False  False   False  False          False            False
# 1            False  False   False  False          False            False
# 2            False  False   False  False          False            False
# 3            False  False   False  False          False            False
# 4            False  False   False  False          False            False
# ...            ...    ...     ...    ...            ...              ...
# 999995       False  False   False  False          False            False
# 999996       False  False   False  False          False            False
# 999997       False  False   False  False          False            False
# 999998       False  False   False  False          False            False
# 999999       False  False   False  False          False            False
#
#         sat_score  act_score  attendance_rate  ap_courses  \
# ...

# %%
#if you use isnull(), it will display each cell is empty or not. If you want count of empty cells use this

# %%
data.isnull().sum()
# Out:
# student_id               0
# age                      0
# gender                   0
# state                    0
# family_income            0
# high_school_gpa          0
# sat_score                0
# act_score                0
# attendance_rate          0
# ap_courses               0
# extracurricular_count    0
# volunteer_hours          0
# leadership_positions     0
# coding_projects          0
# social_media_hours       0
# online_certifications    0
# essay_score              0
# recommendation_score     0
# interview_score          0
# admission_status         0
# dtype: int64

# %%
#no null values, so now remove unwanted columns for our module

# %%
anadata = data.drop(['attendance_rate','ap_courses','online_certifications','essay_score','recommendation_score'],axis =1)
anadata
# Out:
#         student_id  age  gender       state  family_income  high_school_gpa  \
# 0                1   22    Male        Ohio          32560             3.20
# 1                2   19    Male    Virginia          39084             4.00
# 2                3   20    Male        Ohio          21615             2.90
# 3                4   22    Male    Illinois         109493             3.86
# 4                5   18    Male     Florida          50314             2.50
# ...            ...  ...     ...         ...            ...              ...
# 999995      999996   20  Female    New York         127978             3.98
# 999996      999997   16    Male        Ohio          47661             3.49
# 999997      999998   21  Female  Washington          88044             2.77
# 999998      999999   17  Female    Virginia          55654             3.71
# 999999     1000000   18    Male  California          59923             3.41
#
# ...

# %%
#relationship analysis

# %%
scor = anadata[["family_income","admission_status"]].corr()
sns.heatmap(scor, annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(anadata, hue='admission_status')
